# %%
import pandas as pd
from statsmodels.regression.linear_model import OLS
import numpy as np
import scipy.stats as st

# %%
dataframe = pd.read_csv("ps5_data.csv", sep="\t", index_col=0)

# %%
dataframe
# Out:
#       nearc2  nearc4  nearc4a  nearc4b  ed76  ed66  age76  daded  nodaded  \
# id
# 2          0       0        0        0     7     5     29   9.94        1
# 3          0       0        0        0    12    11     27   8.00        0
# 4          0       0        0        0    12    12     34  14.00        0
# 5          1       1        1        0    11    11     27  11.00        0
# 6          1       1        1        0    12    12     34   8.00        0
# ...      ...     ...      ...      ...   ...   ...    ...    ...      ...
# 5219       0       1        1        0    13    12     34   9.94        1
# 5220       0       1        1        0    12     9     24  11.00        0
# 5221       0       1        1        0    12    12     31   9.94        1
# 5224       0       1        1        0     8     8     28   0.00        0
# 5225       0       1        1        0    13    10     26   9.94        1
#
#       momed  ...  noint80  enroll76  enroll78  enroll80   kww     iq  \
# ...
